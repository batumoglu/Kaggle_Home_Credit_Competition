# %%
import pandas as pd
import numpy as np

# %%
buro = pd.read_csv('../input/bureau.csv')

# %%
dtype_df = buro.dtypes.reset_index()
dtype_df.columns = ["Count", "Type"]
dtype_df[dtype_df['Type']=='int64']
# Out:
#                  Count   Type
# 0           SK_ID_CURR  int64
# 1         SK_ID_BUREAU  int64
# 4          DAYS_CREDIT  int64
# 5   CREDIT_DAY_OVERDUE  int64
# 9   CNT_CREDIT_PROLONG  int64
# 15  DAYS_CREDIT_UPDATE  int64

# %%
buro['DAYS_CREDIT_UPDATE'].value_counts()
# Out:
# -7        18503
# -8        18462
# -11       16975
# -15       16870
# -12       16827
# -10       16651
# -9        16546
# -13       16387
# -6        16281
# -14       16210
# -18       15733
# -16       15655
# -17       15041
# -19       14900
# -5        13755
# -22       13572
# -23       13263
# -20       13140
# -21       13041
# -24       12380
# -25       12321
# -26       11683
# -4        11578
# -28       11122
# -29       11054
# -27       10854
# -30        9906
# -3         9542
# -31        9127
# -32        9041
#           ...
# -41864        1
# -41923        1
# -41861        1
# -2862         1
# -41933        1
#  15           1
# -41873        1
# -41940        1
# -41881        1
# -2851         1
# -2844         1
# -2845         1
#  22           1
# -41857        1
# -41859        1
# -2870         1
# -41860        1
#  372          1
# -41869        1
# -41926        1
#  19           1
# -41871        1
# -41872        1
# -41925        1
# ...

# %%
total = 0
for column in buro.columns:
    if buro[column].dtypes=='O':
        display(buro[column].value_counts())
        total +=1
print(total)
# Out:
# Closed      1079273
# Active       630607
# Sold           6527
# Bad debt         21
# Name: CREDIT_ACTIVE, dtype: int64
# currency 1    1715020
# currency 2       1224
# currency 3        174
# currency 4         10
# Name: CREDIT_CURRENCY, dtype: int64
# Consumer credit                                 1251615
# Credit card                                      402195
# Car loan                                          27690
# Mortgage                                          18391
# Microloan                                         12413
# Loan for business development                      1975
# Another type of loan                               1017
# Unknown type of loan                                555
# Loan for working capital replenishment              469
# Cash loan (non-earmarked)                            56
# Real estate loan                                     27
# Loan for the purchase of equipment                   19
# ...

# %%
buro['SK_ID_CURR'].value_counts()
# Out:
# 120860    116
# 169704     94
# 318065     78
# 251643     61
# 425396     60
# 295809     59
# 129843     58
# 385133     57
# 177014     56
# 325354     55
# 252366     55
# 218175     55
# 280155     55
# 281455     54
# 430261     54
# 246770     54
# 260762     53
# 241096     52
# 280042     51
# 220625     51
# 341845     50
# 394986     50
# 164261     50
# 245562     49
# 403382     49
# 207189     49
# 329272     48
# 310637     48
# 162711     47
# 260854     47
#          ...
# 368691      1
# 264496      1
# 184093      1
# 289084      1
# 183785      1
# 434259      1
# 174290      1
# 167393      1
# 149710      1
# 440210      1
# 400755      1
# 404853      1
# 133318      1
# 137412      1
# 364404      1
# 417679      1
# 417147      1
# 116926      1
# 118973      1
# 105859      1
# 124300      1
# 234946      1
# 380796      1
# 236995      1
# 245191      1
# 206292      1
# 216537      1
# 106359      1
# 100212      1
# 250544      1
# ...

# %%
buro['CREDIT_DAY_OVERDUE'].value_counts()
# Out:
# 0       1712211
# 30          311
# 60          126
# 13          103
# 8           103
# 9            93
# 7            92
# 14           91
# 17           77
# 11           75
# 15           74
# 10           71
# 12           70
# 20           68
# 21           64
# 18           63
# 6            59
# 22           54
# 19           54
# 5            51
# 16           50
# 28           50
# 4            46
# 29           46
# 26           43
# 24           42
# 23           41
# 25           40
# 31           38
# 32           36
#          ...
# 1506          1
# 1505          1
# 2528          1
# 1529          1
# 514           1
# 1573          1
# 1556          1
# 1572          1
# 547           1
# 1570          1
# 2595          1
# 544           1
# 2591          1
# 2588          1
# 537           1
# 2585          1
# 2580          1
# 2581          1
# 515           1
# 531           1
# 1554          1
# 1552          1
# 2577          1
# 2574          1
# ...

# %%
buro['CNT_CREDIT_PROLONG'].value_counts()
# Out:
# 0    1707314
# 1       7620
# 2       1222
# 3        191
# 4         54
# 5         21
# 9          2
# 6          2
# 8          1
# 7          1
# Name: CNT_CREDIT_PROLONG, dtype: int64

# %%
buro[(buro['SK_ID_CURR']==329272) & (buro['CREDIT_ACTIVE']=='Active')].sort_values(by='DAYS_CREDIT', ascending=False)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 399495       329272       5085235        Active      currency 1          -10
# 399523       329272       5085270        Active      currency 1          -74
# 1713165      329272       5085254        Active      currency 1          -78
# 399496       329272       5085236        Active      currency 1         -131
# 399510       329272       5085255        Active      currency 1         -145
# 399521       329272       5085268        Active      currency 1         -168
# 399498       329272       5085240        Active      currency 1         -191
# 399520       329272       5085267        Active      currency 1         -229
# 399519       329272       5085266        Active      currency 1         -230
# 1713162      329272       5085239        Active      currency 1         -253
# 1713163      329272       5085242        Active      currency 1         -253
# ...

# %%
buro[buro['SK_ID_CURR']==329272].sort_values(by='DAYS_CREDIT', ascending=False)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 399495       329272       5085235        Active      currency 1          -10
# 399523       329272       5085270        Active      currency 1          -74
# 1713165      329272       5085254        Active      currency 1          -78
# 399488       329272       5085227        Closed      currency 1          -83
# 399522       329272       5085269        Closed      currency 1          -98
# 399508       329272       5085252        Closed      currency 1         -124
# 399496       329272       5085236        Active      currency 1         -131
# 399510       329272       5085255        Active      currency 1         -145
# 399521       329272       5085268        Active      currency 1         -168
# 399498       329272       5085240        Active      currency 1         -191
# 399520       329272       5085267        Active      currency 1         -229
# ...

# %%
buro[(buro['CREDIT_ACTIVE']=='Active') & (buro['AMT_CREDIT_SUM']==0)]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 21           222183       5714491        Active      currency 1         -784
# 166          373324       5714674        Active      currency 1         -837
# 216          451241       5714737        Active      currency 1        -1321
# 222          383257       5714746        Active      currency 1         -601
# 268          390784       5714807        Active      currency 1        -1537
# 324          271160       5714881        Active      currency 1        -1736
# 356          452711       5714928        Active      currency 1         -744
# 436          233056       5715038        Active      currency 1         -482
# 473          388014       5715083        Active      currency 1        -1089
# 516          224915       5715137        Active      currency 1         -244
# 552          309299       5715179        Active      currency 1         -743
# ...

# %%
buro[(buro['CREDIT_TYPE']=='Credit card')]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1            215354       5714463        Active      currency 1         -208
# 3            215354       5714465        Active      currency 1         -203
# 5            215354       5714467        Active      currency 1         -273
# 9            162297       5714471        Active      currency 1        -1146
# 10           162297       5714472        Active      currency 1        -1146
# 14           238881       5714482        Closed      currency 1         -318
# 18           238881       5714487        Active      currency 1          -95
# 20           238881       5714489        Active      currency 1         -392
# 21           222183       5714491        Active      currency 1         -784
# 22           222183       5714492        Active      currency 1         -774
# 31           136226       5714502        Active      currency 1         -521
# ...

# %%
buro[(buro['CREDIT_TYPE']=='Credit card') & (buro['AMT_CREDIT_SUM']>0) & (buro['AMT_CREDIT_SUM_DEBT']<0)]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 87           119939       5714568        Closed      currency 1        -1447
# 88           119939       5714569        Closed      currency 1        -1390
# 89           119939       5714570        Active      currency 1        -1390
# 125          293201       5714621        Closed      currency 1        -2389
# 225          435368       5714751        Active      currency 1        -2915
# 236          228777       5714770        Closed      currency 1        -2264
# 297          333498       5714844        Closed      currency 1        -2805
# 300          333498       5714847        Active      currency 1        -1290
# 332          182982       5714891        Active      currency 1        -2314
# 645          251484       5715297        Active      currency 1        -1147
# 655          249072       5715311        Active      currency 1        -2415
# ...

# %%
buro[buro['CREDIT_ACTIVE']=='Active'].sort_values(by='SK_ID_BUREAU', ascending=False)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1705295      134450       6843455        Active      currency 1         -301
# 1705293      134450       6843453        Active      currency 1        -2385
# 1705292      134450       6843452        Active      currency 1         -583
# 1705288      387585       6843446        Active      currency 1         -268
# 1705286      387585       6843444        Active      currency 1         -295
# 1705285      101681       6843443        Active      currency 1         -634
# 1705284      101681       6843442        Active      currency 1         -530
# 1705283      101681       6843441        Active      currency 1         -722
# 1705271      224416       6843427        Active      currency 1         -100
# 1705266      387354       6843422        Active      currency 1         -139
# 1705264      199054       6843420        Active      currency 1         -171
# ...

# %%
buro[(buro['SK_ID_CURR']==166539) & (buro['CREDIT_ACTIVE']=='Active')]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 775087       166539       5429772        Active      currency 1          -52
# 775088       166539       5429773        Active      currency 1          -52
# 775089       166539       5429774        Active      currency 1          -52
# 775090       166539       5429775        Active      currency 1          -52
# 775091       166539       5429777        Active      currency 1          -52
# 775092       166539       5429778        Active      currency 1          -52
# 775093       166539       5429779        Active      currency 1          -52
# 1307928      166539       5429776        Active      currency 1         -627
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 775087                    0               1796.0                NaN
# 775088                    0               1796.0                NaN
# 775089                    0               1796.0                NaN
# ...

# %%
buro[(buro['SK_ID_CURR']==120860) & (buro['DAYS_CREDIT']==-139)]
# Out:
#         SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 880894      120860       6800829        Closed      currency 1         -139
# 880903      120860       6800840        Closed      currency 1         -139
#
#         CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 880894                   0                  NaN              -76.0
# 880903                   0               -120.0             -120.0
#
#         AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 880894                     NaN                   0         36000.0
# 880903                     NaN                   0         45000.0
#
#         AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 880894                  0.0                   NaN                     0.0
# 880903                  0.0                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# ...
